# %%
import pandas as pd
from openbb_terminal.sdk import openbb
from sklearn.preprocessing import MinMaxScaler

# %%
from libs.backtester import BTData

t = BTData('QQQ')
# Out:
# test2!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from libs.backtester import BTData
# ----> 3 t = BTData('QQQ')
#
# File c:\users\user\desktop\projects\trading\libs\backtester.py:19, in BTData.__init__(self, ticker, start_date, end_date, split_yearly)
#      17 self.end_date = end_date or datetime.now().strftime('%Y-%m-%d')
#      18 if split_yearly:
# ---> 19     self.yearly_date_ranges = self._generate_yearly_date_ranges(self.start_date, self.end_date)
#      20 else:
#      21     self.yearly_date_ranges = [(self.start_date, self.end)]
#
# File c:\users\user\desktop\projects\trading\libs\backtester.py:26, in BTData._generate_yearly_date_ranges(self, start_date, end_date)
#      24 def _generate_yearly_date_ranges(self, start_date, end_date):
#      25     # Convert start_date and end_date to datetime objects
# ---> 26     start_date = datetime.strptime(start_date, '%Y-%m-%d')
#      27     end_date = datetime.strptime(end_date, '%Y-%m-%d')
#      29     # Initialize a list to store the yearly date ranges
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
price_qqq = openbb.stocks.load('QQQ', start_date='2018-01-01', end_date='2022-01-01')
price_vxx = openbb.stocks.load('VXX', start_date='2018-01-01', end_date='2022-01-01')
price_vxz = openbb.stocks.load('VXZ', start_date='2018-01-01', end_date='2022-01-01')
# Out:
# Loading Daily data for QQQ with starting period 2018-01-02.
# Loading Daily data for VXX with starting period 2018-01-25.
# Loading Daily data for VXZ with starting period 2018-01-25.

# %%
price_vxx.Close.plot()
# Out:
# <Axes: xlabel='date'>

# %%
price_vxz.Close.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_similar = openbb.stocks.ca.hist(['QQQ', 'VXX'])
mm_scale = MinMaxScaler()
df_similar = pd.DataFrame(
    mm_scale.fit_transform(df_similar),
    columns=df_similar.columns,
    index=df_similar.index,
)
df_similar.head()
# Out:
#                  QQQ       VXX
# Date
# 2023-04-13  0.065867  0.967818
# 2023-04-14  0.061561  0.943089
# 2023-04-17  0.063499  0.905488
# 2023-04-18  0.063642  0.896680
# 2023-04-19  0.062566  0.891599

# %%
(df_similar['QQQ'] + df_similar['VXX']).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_similar['QQQ'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
openbb.stocks.ca.hist_chart(['QQQ', 'VXX'])
